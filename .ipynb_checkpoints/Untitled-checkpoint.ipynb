# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('bodyfat.csv')
df.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
def plotdistplots(col):
    plt.figure(figsize=(12,5))
    sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
    sn.distplot(df[col], color = 'red', hist=False, label=col)
    plt.legend()
    plt.show()

cols = list(df.columns)
for i in cols:
    print(f'Distribution plots for {i} feature is shown ')
    plotdistplots(i)
    print("-"*100)
# Out:
# Distribution plots for Density feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for BodyFat feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Age feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Weight feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Height feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Neck feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Chest feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Abdomen feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Hip feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Thigh feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Knee feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Ankle feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Biceps feature is shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Forearm feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Wrist feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------

# %%
import scipy.stats as stats

# %%
def drawplots(df, col):
    plt.figure(figsize=(15,7))
    plt.subplot(1,3,1)
    plt.hist(df[col],color='magenta')

    plt.subplot(1,3,2)
    stats.probplot(df[col], dist='norm', plot=plt)

    plt.subplot(1,3,3)
    sn.boxplot(df[col],color='magenta')

    plt.show()

cols = list(df.columns)
for i in range(len(cols)):
    print(f'Distribution plots for the feature {cols[i]} are shown ⬇')
    drawplots(df, cols[i])
    print("="*100)
# Out:
# Distribution plots for the feature Density are shown ⬇
# ====================================================================================================
# Distribution plots for the feature BodyFat are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Age are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Weight are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Height are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Neck are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Chest are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Abdomen are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Hip are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Thigh are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Knee are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Ankle are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Biceps are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Forearm are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Wrist are shown ⬇
# ====================================================================================================

# %%
upperlimit = []
lowerlimit = []
for i in df.columns:
    upperlimit.append(df[i].mean()+(df[i].std())*4)
    lowerlimit.append(df[i].mean()-(df[i].std())*4)

# %%
cols = list(df.columns)
j = 0
for i in range(len(cols)):
    temp = df.loc[(df[cols[i]] > upperlimit[j]) & (df[cols[i]] < lowerlimit[j])]
    j += 1

# %%
temp
# Out:
# Empty DataFrame
# Columns: [Density, BodyFat, Age, Weight, Height, Neck, Chest, Abdomen, Hip, Thigh, Knee, Ankle, Biceps, Forearm, Wrist]
# Index: []

# %%
data = df.copy()
test = data['BodyFat']
train = data.drop(['BodyFat'],axis=1)

# %%
from sklearn.ensemble import ExtraTreesRegressor
er = ExtraTreesRegressor()
er.fit(train,test)
# Out:
# ExtraTreesRegressor()

# %%
series = pd.Series(er.feature_importances_, index=train.columns)
series.nlargest(5).plot(kind='barh', color='green')
# Out:
# <Axes: >

# %%
from sklearn.feature_selection import mutual_info_regression
mr = mutual_info_regression(train, test)

# %%
plotdata = pd.Series(mr, index=train.columns)
plotdata.nlargest(5).plot(kind='barh', color='green')
# Out:
# <Axes: >

# %%
data
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %%
plt.figure(figsize=(15,7))
sn.heatmap(df.corr(), annot=True, cmap='plasma')
# Out:
# <Axes: >

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]>

# %%
def correlation(df, threshold):
    colcor = set()
    
    cormat = df.corr()
    for i in range(len(cormat)):
        for j in range(i):
            '''
            for each cell get the value of that cell by .iloc[i][j],
            where i is the row and j is the col if that abs(value) is greater
            than the threshold, get the col_name and add it in the set
            '''
            if abs(cormat.iloc[i, j]) > threshold:
                colname = cormat.columns[i]
                colcor.add(colname)
    
    return colcor

ans = correlation(train, threshold=0.85)
ans
# Out:
# {'Abdomen', 'Chest', 'Hip', 'Knee', 'Thigh'}

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
temp = data[list(data.columns)]
info = pd.DataFrame()
info['VIF'] = [variance_inflation_factor(temp.values, i) for i in range(temp.shape[1])]
info['Column'] = temp.columns
info
# Out:
#             VIF   Column
# 0   3695.622377  Density
# 1     33.845429  BodyFat
# 2     31.376101      Age
# 3   1238.097164   Weight
# 4    613.410514   Height
# 5   1081.965633     Neck
# 6   1374.457425    Chest
# 7   1332.624257  Abdomen
# 8   2933.636131      Hip
# 9   1017.257501    Thigh
# 10  1187.890413     Knee
# 11   356.293529    Ankle
# 12   419.391664   Biceps
# 13   454.571766  Forearm
# 14  1349.973920    Wrist

# %%
cols1 = list(series.nlargest(5).index)
cols2 = list(plotdata.nlargest(5).index)

cols1, cols2
# Out:
# (['Density', 'Abdomen', 'Chest', 'Hip', 'Thigh'],
#  ['Density', 'Abdomen', 'Chest', 'Hip', 'Weight'])

# %%
totrain = train[cols1]
totrain.head()
# Out:
#    Density  Abdomen  Chest    Hip  Thigh
# 0   1.0708     85.2   93.1   94.5   59.0
# 1   1.0853     83.0   93.6   98.7   58.7
# 2   1.0414     87.9   95.8   99.2   59.6
# 3   1.0751     86.4  101.8  101.2   60.1
# 4   1.0340    100.0   97.3  101.9   63.2

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn import metrics
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %%
X_train, X_test, y_train, y_test = train_test_split(totrain, test, test_size=0.2)
X_train.shape, X_test.shape
# Out:
# ((201, 5), (51, 5))

# %%
reg = DecisionTreeRegressor()
reg.fit(X_train, y_train)
plt.figure(figsize=(15,7))
tree.plot_tree(reg, filled=True)
# Out:
# [Text(0.4712301587301587, 0.9583333333333334, 'x[0] <= 1.053\nsquared_error = 74.564\nsamples = 201\nvalue = 19.488'),
#  Text(0.2089002267573696, 0.875, 'x[0] <= 1.036\nsquared_error = 26.551\nsamples = 96\nvalue = 26.903'),
#  Text(0.3400651927437642, 0.9166666666666667, 'True  '),
#  Text(0.061507936507936505, 0.7916666666666666, 'x[0] <= 1.016\nsquared_error = 13.293\nsamples = 39\nvalue = 32.054'),
#  Text(0.009070294784580499, 0.7083333333333334, 'x[0] <= 1.003\nsquared_error = 16.347\nsamples = 3\nvalue = 41.9'),
#  Text(0.0045351473922902496, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 47.5'),
#  Text(0.013605442176870748, 0.625, 'x[0] <= 1.012\nsquared_error = 1.0\nsamples = 2\nvalue = 39.1'),
#  Text(0.009070294784580499, 0.5416666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 40.1'),
#  Text(0.018140589569160998, 0.5416666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 38.1'),
#  Text(0.11394557823129252, 0.7083333333333334, 'x[0] <= 1.029\nsquared_error = 4.286\nsamples = 36\nvalue = 31.233'),
#  Text(0.05782312925170068, 0.625, 'x[0] <= 1.024\nsquared_error = 1.57\nsamples = 19\nvalue = 32.916'),
#  Text(0.027210884353741496, 0.5416666666666666, 'x[2] <= 117.25\nsquared_error = 0.276\nsamples = 6\nvalue = 34.567'),
#  Text(0.015873015873015872, 0.4583333333333333, 'x[1] <= 110.45\nsquared_error = 0.122\nsamples = 2\nvalue = 33.95'),
#  Text(0.011337868480725623, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 33.6'),
#  Text(0.02040816326530612, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 34.3'),
#  Text(0.03854875283446712, 0.4583333333333333, 'x[0] <= 1.021\nsquared_error = 0.067\nsamples = 4\nvalue = 34.875'),
#  Text(0.02947845804988662, 0.375, 'x[4] <= 74.3\nsquared_error = 0.01\nsamples = 2\nvalue = 35.1'),
#  Text(0.024943310657596373, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 35.0'),
#  Text(0.034013605442176874, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 35.2'),
#  Text(0.047619047619047616, 0.375, 'x[4] <= 68.0\nsquared_error = 0.023\nsamples = 2\nvalue = 34.65'),
#  Text(0.04308390022675737, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 34.8'),
#  Text(0.05215419501133787, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 34.5'),
#  Text(0.08843537414965986, 0.5416666666666666, 'x[0] <= 1.027\nsquared_error = 0.329\nsamples = 13\nvalue = 32.154'),
#  Text(0.07482993197278912, 0.4583333333333333, 'x[0] <= 1.026\nsquared_error = 0.056\nsamples = 7\nvalue = 32.629'),
#  Text(0.07029478458049887, 0.375, 'x[2] <= 110.4\nsquared_error = 0.018\nsamples = 5\nvalue = 32.76'),
#  Text(0.061224489795918366, 0.2916666666666667, 'x[0] <= 1.025\nsquared_error = 0.002\nsamples = 3\nvalue = 32.867'),
#  Text(0.05668934240362812, 0.20833333333333334, 'squared_error = 0.0\nsamples = 2\nvalue = 32.9'),
#  Text(0.06575963718820861, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 32.8'),
#  Text(0.07936507936507936, 0.2916666666666667, 'x[0] <= 1.026\nsquared_error = 0.0\nsamples = 2\nvalue = 32.6'),
#  Text(0.07482993197278912, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 32.6'),
#  Text(0.08390022675736962, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 32.6'),
#  Text(0.07936507936507936, 0.375, 'squared_error = -0.0\nsamples = 2\nvalue = 32.3'),
#  Text(0.10204081632653061, 0.4583333333333333, 'x[0] <= 1.027\nsquared_error = 0.077\nsamples = 6\nvalue = 31.6'),
#  Text(0.09297052154195011, 0.375, 'x[2] <= 109.5\nsquared_error = 0.002\nsamples = 2\nvalue = 31.95'),
#  Text(0.08843537414965986, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 32.0'),
#  Text(0.09750566893424037, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 31.9'),
#  Text(0.1111111111111111, 0.375, 'x[0] <= 1.029\nsquared_error = 0.022\nsamples = 4\nvalue = 31.425'),
#  Text(0.10657596371882086, 0.2916666666666667, 'x[1] <= 100.55\nsquared_error = 0.007\nsamples = 3\nvalue = 31.5'),
#  Text(0.10204081632653061, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 31.4'),
#  Text(0.1111111111111111, 0.20833333333333334, 'x[4] <= 63.4\nsquared_error = 0.002\nsamples = 2\nvalue = 31.55'),
#  Text(0.10657596371882086, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 31.5'),
#  Text(0.11564625850340136, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 31.6'),
#  Text(0.11564625850340136, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 31.2'),
#  Text(0.17006802721088435, 0.625, 'x[0] <= 1.033\nsquared_error = 0.622\nsamples = 17\nvalue = 29.353'),
#  Text(0.14285714285714285, 0.5416666666666666, 'x[0] <= 1.031\nsquared_error = 0.17\nsamples = 10\nvalue = 29.92'),
#  Text(0.12471655328798185, 0.4583333333333333, 'x[2] <= 110.65\nsquared_error = 0.042\nsamples = 3\nvalue = 30.433'),
#  Text(0.12018140589569161, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 30.7'),
#  Text(0.1292517006802721, 0.375, 'x[1] <= 108.3\nsquared_error = 0.01\nsamples = 2\nvalue = 30.3'),
#  Text(0.12471655328798185, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 30.2'),
#  Text(0.13378684807256236, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 30.4'),
#  Text(0.16099773242630386, 0.4583333333333333, 'x[0] <= 1.032\nsquared_error = 0.063\nsamples = 7\nvalue = 29.7'),
#  Text(0.1473922902494331, 0.375, 'x[2] <= 102.95\nsquared_error = 0.005\nsamples = 4\nvalue = 29.9'),
#  Text(0.14285714285714285, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 29.8'),
#  Text(0.15192743764172337, 0.2916666666666667, 'x[2] <= 104.7\nsquared_error = 0.002\nsamples = 3\nvalue = 29.933'),
#  Text(0.1473922902494331, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 30.0'),
#  Text(0.1564625850340136, 0.20833333333333334, 'squared_error = -0.0\nsamples = 2\nvalue = 29.9'),
#  Text(0.1746031746031746, 0.375, 'x[4] <= 66.0\nsquared_error = 0.016\nsamples = 3\nvalue = 29.433'),
#  Text(0.17006802721088435, 0.2916666666666667, 'x[0] <= 1.033\nsquared_error = 0.003\nsamples = 2\nvalue = 29.35'),
#  Text(0.1655328798185941, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 29.4'),
#  Text(0.1746031746031746, 0.20833333333333334, 'squared_error = -0.0\nsamples = 1\nvalue = 29.3'),
#  Text(0.17913832199546487, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 29.6'),
#  Text(0.19727891156462585, 0.5416666666666666, 'x[0] <= 1.034\nsquared_error = 0.154\nsamples = 7\nvalue = 28.543'),
#  Text(0.18820861678004536, 0.4583333333333333, 'x[0] <= 1.034\nsquared_error = 0.022\nsamples = 4\nvalue = 28.85'),
#  Text(0.1836734693877551, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 29.0'),
#  Text(0.1927437641723356, 0.375, 'squared_error = -0.0\nsamples = 2\nvalue = 28.7'),
#  Text(0.20634920634920634, 0.4583333333333333, 'x[1] <= 101.5\nsquared_error = 0.036\nsamples = 3\nvalue = 28.133'),
#  Text(0.2018140589569161, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 28.4'),
#  Text(0.2108843537414966, 0.375, 'squared_error = -0.0\nsamples = 2\nvalue = 28.0'),
#  Text(0.3562925170068027, 0.7916666666666666, 'x[0] <= 1.046\nsquared_error = 5.05\nsamples = 57\nvalue = 23.379'),
#  Text(0.286281179138322, 0.7083333333333334, 'x[0] <= 1.041\nsquared_error = 1.066\nsamples = 26\nvalue = 25.577'),
#  Text(0.2494331065759637, 0.625, 'x[0] <= 1.039\nsquared_error = 0.251\nsamples = 12\nvalue = 26.542'),
#  Text(0.23356009070294784, 0.5416666666666666, 'x[0] <= 1.038\nsquared_error = 0.062\nsamples = 7\nvalue = 26.929'),
#  Text(0.22448979591836735, 0.4583333333333333, 'x[0] <= 1.038\nsquared_error = 0.017\nsamples = 4\nvalue = 27.125'),
#  Text(0.2199546485260771, 0.375, 'x[2] <= 108.15\nsquared_error = 0.003\nsamples = 2\nvalue = 27.25'),
#  Text(0.21541950113378686, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 27.2'),
#  Text(0.22448979591836735, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 27.3'),
#  Text(0.2290249433106576, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 27.0'),
#  Text(0.24263038548752835, 0.4583333333333333, 'x[3] <= 105.0\nsquared_error = 0.002\nsamples = 3\nvalue = 26.667'),
#  Text(0.23809523809523808, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 26.7'),
#  Text(0.2471655328798186, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 26.6'),
#  Text(0.2653061224489796, 0.5416666666666666, 'x[4] <= 64.4\nsquared_error = 0.012\nsamples = 5\nvalue = 26.0'),
#  Text(0.26077097505668934, 0.4583333333333333, 'x[0] <= 1.04\nsquared_error = 0.002\nsamples = 4\nvalue = 26.05'),
#  Text(0.2562358276643991, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 26.1'),
#  Text(0.2653061224489796, 0.375, 'x[1] <= 105.85\nsquared_error = 0.0\nsamples = 2\nvalue = 26.0'),
#  Text(0.26077097505668934, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 26.0'),
#  Text(0.2698412698412698, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 26.0'),
#  Text(0.2698412698412698, 0.4583333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 25.8'),
#  Text(0.3231292517006803, 0.625, 'x[0] <= 1.043\nsquared_error = 0.283\nsamples = 14\nvalue = 24.75'),
#  Text(0.30385487528344673, 0.5416666666666666, 'x[0] <= 1.042\nsquared_error = 0.057\nsamples = 7\nvalue = 25.2'),
#  Text(0.2925170068027211, 0.4583333333333333, 'x[0] <= 1.041\nsquared_error = 0.01\nsamples = 5\nvalue = 25.34'),
#  Text(0.2834467120181406, 0.375, 'x[3] <= 100.05\nsquared_error = 0.002\nsamples = 2\nvalue = 25.45'),
#  Text(0.2789115646258503, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 25.4'),
#  Text(0.28798185941043086, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 25.5'),
#  Text(0.30158730158730157, 0.375, 'x[0] <= 1.041\nsquared_error = 0.002\nsamples = 3\nvalue = 25.267'),
#  Text(0.29705215419501135, 0.2916666666666667, 'x[1] <= 103.45\nsquared_error = 0.0\nsamples = 2\nvalue = 25.3'),
#  Text(0.2925170068027211, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 25.3'),
#  Text(0.30158730158730157, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 25.3'),
#  Text(0.30612244897959184, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 25.2'),
#  Text(0.31519274376417233, 0.4583333333333333, 'x[3] <= 101.35\nsquared_error = 0.002\nsamples = 2\nvalue = 24.85'),
#  Text(0.31065759637188206, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.3197278911564626, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 24.9'),
#  Text(0.3424036281179138, 0.5416666666666666, 'x[0] <= 1.045\nsquared_error = 0.103\nsamples = 7\nvalue = 24.3'),
#  Text(0.3378684807256236, 0.4583333333333333, 'x[2] <= 106.6\nsquared_error = 0.025\nsamples = 6\nvalue = 24.417'),
#  Text(0.3287981859410431, 0.375, 'x[0] <= 1.044\nsquared_error = 0.007\nsamples = 4\nvalue = 24.325'),
#  Text(0.3242630385487528, 0.2916666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 24.4'),
#  Text(0.3333333333333333, 0.2916666666666667, 'x[4] <= 60.05\nsquared_error = 0.002\nsamples = 2\nvalue = 24.25'),
#  Text(0.3287981859410431, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.3378684807256236, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 24.2'),
#  Text(0.3469387755102041, 0.375, 'x[3] <= 108.4\nsquared_error = 0.01\nsamples = 2\nvalue = 24.6'),
#  Text(0.3424036281179138, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.35147392290249435, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 24.7'),
#  Text(0.3469387755102041, 0.4583333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 23.6'),
#  Text(0.42630385487528344, 0.7083333333333334, 'x[0] <= 1.05\nsquared_error = 0.942\nsamples = 31\nvalue = 21.535'),
#  Text(0.3900226757369615, 0.625, 'x[0] <= 1.047\nsquared_error = 0.258\nsamples = 15\nvalue = 22.42'),
#  Text(0.36961451247165533, 0.5416666666666666, 'x[3] <= 99.0\nsquared_error = 0.122\nsamples = 4\nvalue = 23.125'),
#  Text(0.36054421768707484, 0.4583333333333333, 'x[3] <= 96.55\nsquared_error = 0.022\nsamples = 2\nvalue = 23.45'),
#  Text(0.35600907029478457, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 23.6'),
#  Text(0.36507936507936506, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.3786848072562358, 0.4583333333333333, 'x[3] <= 103.05\nsquared_error = 0.01\nsamples = 2\nvalue = 22.8'),
#  Text(0.3741496598639456, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 22.7'),
#  Text(0.3832199546485261, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.41043083900226757, 0.5416666666666666, 'x[0] <= 1.048\nsquared_error = 0.06\nsamples = 11\nvalue = 22.164'),
#  Text(0.3968253968253968, 0.4583333333333333, 'x[2] <= 99.7\nsquared_error = 0.007\nsamples = 3\nvalue = 22.5'),
#  Text(0.3922902494331066, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 22.4'),
#  Text(0.4013605442176871, 0.375, 'x[2] <= 104.35\nsquared_error = 0.002\nsamples = 2\nvalue = 22.55'),
#  Text(0.3968253968253968, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 22.5'),
#  Text(0.40589569160997735, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.42403628117913833, 0.4583333333333333, 'x[0] <= 1.049\nsquared_error = 0.022\nsamples = 8\nvalue = 22.038'),
#  Text(0.41950113378684806, 0.375, 'x[2] <= 101.65\nsquared_error = 0.005\nsamples = 6\nvalue = 22.117'),
#  Text(0.41496598639455784, 0.2916666666666667, 'x[3] <= 96.55\nsquared_error = 0.002\nsamples = 4\nvalue = 22.075'),
#  Text(0.41043083900226757, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.41950113378684806, 0.20833333333333334, 'squared_error = -0.0\nsamples = 3\nvalue = 22.1'),
#  Text(0.42403628117913833, 0.2916666666666667, 'squared_error = -0.0\nsamples = 2\nvalue = 22.2'),
#  Text(0.42857142857142855, 0.375, 'squared_error = -0.0\nsamples = 2\nvalue = 21.8'),
#  Text(0.46258503401360546, 0.625, 'x[0] <= 1.052\nsquared_error = 0.163\nsamples = 16\nvalue = 20.706'),
#  Text(0.4512471655328798, 0.5416666666666666, 'x[0] <= 1.051\nsquared_error = 0.05\nsamples = 8\nvalue = 21.062'),
#  Text(0.4421768707482993, 0.4583333333333333, 'x[3] <= 101.15\nsquared_error = 0.028\nsamples = 5\nvalue = 21.2'),
#  Text(0.4376417233560091, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 21.4'),
#  Text(0.4467120181405896, 0.375, 'x[1] <= 94.7\nsquared_error = 0.023\nsamples = 4\nvalue = 21.15'),
#  Text(0.4421768707482993, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.4512471655328798, 0.2916666666666667, 'x[2] <= 109.1\nsquared_error = 0.002\nsamples = 3\nvalue = 21.233'),
#  Text(0.4467120181405896, 0.20833333333333334, 'squared_error = -0.0\nsamples = 2\nvalue = 21.2'),
#  Text(0.4557823129251701, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 21.3'),
#  Text(0.4603174603174603, 0.4583333333333333, 'x[0] <= 1.051\nsquared_error = 0.002\nsamples = 3\nvalue = 20.833'),
#  Text(0.4557823129251701, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.46485260770975056, 0.375, 'x[3] <= 101.7\nsquared_error = 0.0\nsamples = 2\nvalue = 20.8'),
#  Text(0.4603174603174603, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(0.46938775510204084, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(0.47392290249433106, 0.5416666666666666, 'x[2] <= 97.9\nsquared_error = 0.022\nsamples = 8\nvalue = 20.35'),
#  Text(0.46938775510204084, 0.4583333333333333, 'squared_error = 0.0\nsamples = 2\nvalue = 20.1'),
#  Text(0.47845804988662133, 0.4583333333333333, 'x[0] <= 1.052\nsquared_error = 0.002\nsamples = 6\nvalue = 20.433'),
#  Text(0.47392290249433106, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 20.5'),
#  Text(0.48299319727891155, 0.375, 'squared_error = 0.0\nsamples = 4\nvalue = 20.4'),
#  Text(0.7335600907029478, 0.875, 'x[0] <= 1.066\nsquared_error = 22.23\nsamples = 105\nvalue = 12.709'),
#  Text(0.6023951247165533, 0.9166666666666667, '  False'),
#  Text(0.594671201814059, 0.7916666666666666, 'x[0] <= 1.059\nsquared_error = 2.615\nsamples = 43\nvalue = 17.188'),
#  Text(0.5430839002267573, 0.7083333333333334, 'x[0] <= 1.056\nsquared_error = 0.477\nsamples = 22\nvalue = 18.586'),
#  Text(0.5079365079365079, 0.625, 'x[0] <= 1.055\nsquared_error = 0.099\nsamples = 10\nvalue = 19.25'),
#  Text(0.49206349206349204, 0.5416666666666666, 'x[1] <= 90.15\nsquared_error = 0.007\nsamples = 4\nvalue = 19.575'),
#  Text(0.4875283446712018, 0.4583333333333333, 'squared_error = 0.0\nsamples = 2\nvalue = 19.5'),
#  Text(0.4965986394557823, 0.4583333333333333, 'x[1] <= 96.75\nsquared_error = 0.002\nsamples = 2\nvalue = 19.65'),
#  Text(0.49206349206349204, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 19.7'),
#  Text(0.5011337868480725, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.5238095238095238, 0.5416666666666666, 'x[0] <= 1.056\nsquared_error = 0.042\nsamples = 6\nvalue = 19.033'),
#  Text(0.5147392290249433, 0.4583333333333333, 'x[0] <= 1.055\nsquared_error = 0.002\nsamples = 4\nvalue = 19.175'),
#  Text(0.5102040816326531, 0.375, 'squared_error = 0.0\nsamples = 3\nvalue = 19.2'),
#  Text(0.5192743764172335, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 19.1'),
#  Text(0.5328798185941043, 0.4583333333333333, 'x[3] <= 102.2\nsquared_error = 0.002\nsamples = 2\nvalue = 18.75'),
#  Text(0.528344671201814, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 18.8'),
#  Text(0.5374149659863946, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 18.7'),
#  Text(0.5782312925170068, 0.625, 'x[0] <= 1.058\nsquared_error = 0.119\nsamples = 12\nvalue = 18.033'),
#  Text(0.564625850340136, 0.5416666666666666, 'x[0] <= 1.057\nsquared_error = 0.033\nsamples = 8\nvalue = 18.25'),
#  Text(0.5510204081632653, 0.4583333333333333, 'x[4] <= 55.1\nsquared_error = 0.015\nsamples = 4\nvalue = 18.4'),
#  Text(0.546485260770975, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 18.6'),
#  Text(0.5555555555555556, 0.375, 'x[0] <= 1.057\nsquared_error = 0.002\nsamples = 3\nvalue = 18.333'),
#  Text(0.5510204081632653, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 18.4'),
#  Text(0.5600907029478458, 0.2916666666666667, 'x[1] <= 97.3\nsquared_error = 0.0\nsamples = 2\nvalue = 18.3'),
#  Text(0.5555555555555556, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 18.3'),
#  Text(0.564625850340136, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 18.3'),
#  Text(0.5782312925170068, 0.4583333333333333, 'x[2] <= 101.85\nsquared_error = 0.005\nsamples = 4\nvalue = 18.1'),
#  Text(0.5736961451247166, 0.375, 'x[2] <= 95.45\nsquared_error = 0.002\nsamples = 3\nvalue = 18.067'),
#  Text(0.5691609977324263, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 18.0'),
#  Text(0.5782312925170068, 0.2916666666666667, 'x[1] <= 88.8\nsquared_error = 0.0\nsamples = 2\nvalue = 18.1'),
#  Text(0.5736961451247166, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 18.1'),
#  Text(0.5827664399092971, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 18.1'),
#  Text(0.5827664399092971, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 18.2'),
#  Text(0.5918367346938775, 0.5416666666666666, 'x[0] <= 1.059\nsquared_error = 0.01\nsamples = 4\nvalue = 17.6'),
#  Text(0.5873015873015873, 0.4583333333333333, 'squared_error = 0.0\nsamples = 2\nvalue = 17.7'),
#  Text(0.5963718820861678, 0.4583333333333333, 'squared_error = -0.0\nsamples = 2\nvalue = 17.5'),
#  Text(0.6462585034013606, 0.7083333333333334, 'x[0] <= 1.063\nsquared_error = 0.662\nsamples = 21\nvalue = 15.724'),
#  Text(0.6258503401360545, 0.625, 'x[0] <= 1.062\nsquared_error = 0.148\nsamples = 10\nvalue = 16.5'),
#  Text(0.6145124716553289, 0.5416666666666666, 'x[0] <= 1.061\nsquared_error = 0.036\nsamples = 7\nvalue = 16.729'),
#  Text(0.6054421768707483, 0.4583333333333333, 'x[3] <= 98.45\nsquared_error = 0.002\nsamples = 3\nvalue = 16.933'),
#  Text(0.6009070294784581, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 17.0'),
#  Text(0.6099773242630385, 0.375, 'squared_error = -0.0\nsamples = 2\nvalue = 16.9'),
#  Text(0.6235827664399093, 0.4583333333333333, 'x[4] <= 56.35\nsquared_error = 0.007\nsamples = 4\nvalue = 16.575'),
#  Text(0.6190476190476191, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 16.7'),
#  Text(0.6281179138321995, 0.375, 'x[1] <= 93.55\nsquared_error = 0.002\nsamples = 3\nvalue = 16.533'),
#  Text(0.6235827664399093, 0.2916666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 16.5'),
#  Text(0.6326530612244898, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 16.6'),
#  Text(0.63718820861678, 0.5416666666666666, 'x[1] <= 91.85\nsquared_error = 0.002\nsamples = 3\nvalue = 15.967'),
#  Text(0.6326530612244898, 0.4583333333333333, 'squared_error = 0.0\nsamples = 2\nvalue = 16.0'),
#  Text(0.6417233560090703, 0.4583333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 15.9'),
#  Text(0.6666666666666666, 0.625, 'x[0] <= 1.064\nsquared_error = 0.083\nsamples = 11\nvalue = 15.018'),
#  Text(0.655328798185941, 0.5416666666666666, 'x[0] <= 1.064\nsquared_error = 0.027\nsamples = 4\nvalue = 15.35'),
#  Text(0.6507936507936508, 0.4583333333333333, 'x[1] <= 82.25\nsquared_error = 0.01\nsamples = 2\nvalue = 15.5'),
#  Text(0.6462585034013606, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 15.6'),
#  Text(0.655328798185941, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 15.4'),
#  Text(0.6598639455782312, 0.4583333333333333, 'squared_error = -0.0\nsamples = 2\nvalue = 15.2'),
#  Text(0.6780045351473923, 0.5416666666666666, 'x[4] <= 59.45\nsquared_error = 0.016\nsamples = 7\nvalue = 14.829'),
#  Text(0.6689342403628118, 0.4583333333333333, 'x[4] <= 55.15\nsquared_error = 0.004\nsamples = 5\nvalue = 14.9'),
#  Text(0.6643990929705216, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 15.0'),
#  Text(0.673469387755102, 0.375, 'x[4] <= 56.9\nsquared_error = 0.002\nsamples = 4\nvalue = 14.875'),
#  Text(0.6689342403628118, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 14.8'),
#  Text(0.6780045351473923, 0.2916666666666667, 'squared_error = -0.0\nsamples = 3\nvalue = 14.9'),
#  Text(0.6870748299319728, 0.4583333333333333, 'x[4] <= 60.95\nsquared_error = 0.002\nsamples = 2\nvalue = 14.65'),
#  Text(0.6825396825396826, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 14.7'),
#  Text(0.691609977324263, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 14.6'),
#  Text(0.8724489795918368, 0.7916666666666666, 'x[0] <= 1.078\nsquared_error = 12.262\nsamples = 62\nvalue = 9.602'),
#  Text(0.7919501133786848, 0.7083333333333334, 'x[0] <= 1.073\nsquared_error = 2.859\nsamples = 39\nvalue = 11.497'),
#  Text(0.7380952380952381, 0.625, 'x[0] <= 1.067\nsquared_error = 2.598\nsamples = 25\nvalue = 12.276'),
#  Text(0.7335600907029478, 0.5416666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 5.6'),
#  Text(0.7426303854875284, 0.5416666666666666, 'x[0] <= 1.07\nsquared_error = 0.772\nsamples = 24\nvalue = 12.554'),
#  Text(0.7120181405895691, 0.4583333333333333, 'x[0] <= 1.068\nsquared_error = 0.18\nsamples = 9\nvalue = 13.556'),
#  Text(0.7006802721088435, 0.375, 'x[0] <= 1.067\nsquared_error = 0.036\nsamples = 6\nvalue = 13.833'),
#  Text(0.691609977324263, 0.2916666666666667, 'x[4] <= 57.6\nsquared_error = 0.007\nsamples = 3\nvalue = 14.0'),
#  Text(0.6870748299319728, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 13.9'),
#  Text(0.6961451247165533, 0.20833333333333334, 'x[1] <= 81.4\nsquared_error = 0.002\nsamples = 2\nvalue = 14.05'),
#  Text(0.691609977324263, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 14.0'),
#  Text(0.7006802721088435, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 14.1'),
#  Text(0.7097505668934241, 0.2916666666666667, 'x[1] <= 83.75\nsquared_error = 0.009\nsamples = 3\nvalue = 13.667'),
#  Text(0.7052154195011338, 0.20833333333333334, 'squared_error = 0.0\nsamples = 2\nvalue = 13.6'),
#  Text(0.7142857142857143, 0.20833333333333334, 'squared_error = -0.0\nsamples = 1\nvalue = 13.8'),
#  Text(0.7233560090702947, 0.375, 'x[3] <= 95.35\nsquared_error = 0.007\nsamples = 3\nvalue = 13.0'),
#  Text(0.7188208616780045, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 12.9'),
#  Text(0.7278911564625851, 0.2916666666666667, 'x[1] <= 87.65\nsquared_error = 0.002\nsamples = 2\nvalue = 13.05'),
#  Text(0.7233560090702947, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 13.1'),
#  Text(0.7324263038548753, 0.20833333333333334, 'squared_error = -0.0\nsamples = 1\nvalue = 13.0'),
#  Text(0.7732426303854876, 0.4583333333333333, 'x[0] <= 1.071\nsquared_error = 0.164\nsamples = 15\nvalue = 11.953'),
#  Text(0.7551020408163265, 0.375, 'x[0] <= 1.071\nsquared_error = 0.02\nsamples = 7\nvalue = 12.343'),
#  Text(0.746031746031746, 0.2916666666666667, 'x[1] <= 80.5\nsquared_error = 0.003\nsamples = 4\nvalue = 12.45'),
#  Text(0.7414965986394558, 0.20833333333333334, 'squared_error = 0.0\nsamples = 2\nvalue = 12.5'),
#  Text(0.7505668934240363, 0.20833333333333334, 'x[4] <= 59.45\nsquared_error = 0.0\nsamples = 2\nvalue = 12.4'),
#  Text(0.746031746031746, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(0.7551020408163265, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(0.764172335600907, 0.2916666666666667, 'x[1] <= 86.0\nsquared_error = 0.007\nsamples = 3\nvalue = 12.2'),
#  Text(0.7596371882086168, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 12.3'),
#  Text(0.7687074829931972, 0.20833333333333334, 'x[2] <= 97.5\nsquared_error = 0.002\nsamples = 2\nvalue = 12.15'),
#  Text(0.764172335600907, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.1'),
#  Text(0.7732426303854876, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 12.2'),
#  Text(0.7913832199546486, 0.375, 'x[0] <= 1.072\nsquared_error = 0.041\nsamples = 8\nvalue = 11.612'),
#  Text(0.782312925170068, 0.2916666666666667, 'x[0] <= 1.072\nsquared_error = 0.005\nsamples = 4\nvalue = 11.8'),
#  Text(0.7777777777777778, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 11.9'),
#  Text(0.7868480725623582, 0.20833333333333334, 'x[3] <= 99.3\nsquared_error = 0.002\nsamples = 3\nvalue = 11.767'),
#  Text(0.782312925170068, 0.125, 'x[4] <= 56.4\nsquared_error = 0.0\nsamples = 2\nvalue = 11.8'),
#  Text(0.7777777777777778, 0.041666666666666664, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.7868480725623582, 0.041666666666666664, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.7913832199546486, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.7'),
#  Text(0.800453514739229, 0.2916666666666667, 'x[0] <= 1.073\nsquared_error = 0.007\nsamples = 4\nvalue = 11.425'),
#  Text(0.7959183673469388, 0.20833333333333334, 'squared_error = 0.0\nsamples = 2\nvalue = 11.5'),
#  Text(0.8049886621315193, 0.20833333333333334, 'x[4] <= 58.2\nsquared_error = 0.002\nsamples = 2\nvalue = 11.35'),
#  Text(0.800453514739229, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 11.4'),
#  Text(0.8095238095238095, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 11.3'),
#  Text(0.8458049886621315, 0.625, 'x[0] <= 1.076\nsquared_error = 0.311\nsamples = 14\nvalue = 10.107'),
#  Text(0.8276643990929705, 0.5416666666666666, 'x[3] <= 98.25\nsquared_error = 0.083\nsamples = 7\nvalue = 10.6'),
#  Text(0.81859410430839, 0.4583333333333333, 'x[0] <= 1.074\nsquared_error = 0.022\nsamples = 4\nvalue = 10.825'),
#  Text(0.8140589569160998, 0.375, 'x[0] <= 1.074\nsquared_error = 0.007\nsamples = 3\nvalue = 10.9'),
#  Text(0.8095238095238095, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 11.0'),
#  Text(0.81859410430839, 0.2916666666666667, 'x[2] <= 99.9\nsquared_error = 0.002\nsamples = 2\nvalue = 10.85'),
#  Text(0.8140589569160998, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 10.8'),
#  Text(0.8231292517006803, 0.20833333333333334, 'squared_error = -0.0\nsamples = 1\nvalue = 10.9'),
#  Text(0.8231292517006803, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 10.6'),
#  Text(0.8367346938775511, 0.4583333333333333, 'x[2] <= 93.4\nsquared_error = 0.007\nsamples = 3\nvalue = 10.3'),
#  Text(0.8321995464852607, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.2'),
#  Text(0.8412698412698413, 0.375, 'x[0] <= 1.075\nsquared_error = 0.002\nsamples = 2\nvalue = 10.35'),
#  Text(0.8367346938775511, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 10.4'),
#  Text(0.8458049886621315, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 10.3'),
#  Text(0.8639455782312925, 0.5416666666666666, 'x[0] <= 1.077\nsquared_error = 0.053\nsamples = 7\nvalue = 9.614'),
#  Text(0.854875283446712, 0.4583333333333333, 'x[3] <= 95.85\nsquared_error = 0.003\nsamples = 2\nvalue = 9.95'),
#  Text(0.8503401360544217, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 9.9'),
#  Text(0.8594104308390023, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.0'),
#  Text(0.873015873015873, 0.4583333333333333, 'x[1] <= 82.55\nsquared_error = 0.01\nsamples = 5\nvalue = 9.48'),
#  Text(0.8684807256235828, 0.375, 'x[3] <= 92.5\nsquared_error = 0.0\nsamples = 3\nvalue = 9.4'),
#  Text(0.8639455782312925, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 9.4'),
#  Text(0.873015873015873, 0.2916666666666667, 'squared_error = -0.0\nsamples = 2\nvalue = 9.4'),
#  Text(0.8775510204081632, 0.375, 'squared_error = -0.0\nsamples = 2\nvalue = 9.6'),
#  Text(0.9529478458049887, 0.7083333333333334, 'x[2] <= 108.4\nsquared_error = 11.778\nsamples = 23\nvalue = 6.387'),
#  Text(0.9484126984126984, 0.625, 'x[0] <= 1.087\nsquared_error = 6.549\nsamples = 22\nvalue = 5.886'),
#  Text(0.9172335600907029, 0.5416666666666666, 'x[0] <= 1.082\nsquared_error = 1.071\nsamples = 13\nvalue = 7.692'),
#  Text(0.8979591836734694, 0.4583333333333333, 'x[0] <= 1.08\nsquared_error = 0.188\nsamples = 9\nvalue = 8.311'),
#  Text(0.8866213151927438, 0.375, 'x[0] <= 1.079\nsquared_error = 0.022\nsamples = 5\nvalue = 8.68'),
#  Text(0.8820861678004536, 0.2916666666666667, 'squared_error = -0.0\nsamples = 3\nvalue = 8.8'),
#  Text(0.891156462585034, 0.2916666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 8.5'),
#  Text(0.909297052154195, 0.375, 'x[0] <= 1.081\nsquared_error = 0.013\nsamples = 4\nvalue = 7.85'),
#  Text(0.9002267573696145, 0.2916666666666667, 'x[3] <= 87.2\nsquared_error = 0.002\nsamples = 2\nvalue = 7.95'),
#  Text(0.8956916099773242, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 7.9'),
#  Text(0.9047619047619048, 0.20833333333333334, 'squared_error = -0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.9183673469387755, 0.2916666666666667, 'x[1] <= 83.45\nsquared_error = 0.003\nsamples = 2\nvalue = 7.75'),
#  Text(0.9138321995464853, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 7.7'),
#  Text(0.9229024943310657, 0.20833333333333334, 'squared_error = -0.0\nsamples = 1\nvalue = 7.8'),
#  Text(0.9365079365079365, 0.4583333333333333, 'x[1] <= 79.5\nsquared_error = 0.26\nsamples = 4\nvalue = 6.3'),
#  Text(0.9319727891156463, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 7.1'),
#  Text(0.9410430839002267, 0.375, 'x[3] <= 99.65\nsquared_error = 0.062\nsamples = 3\nvalue = 6.033'),
#  Text(0.9365079365079365, 0.2916666666666667, 'x[3] <= 95.15\nsquared_error = 0.01\nsamples = 2\nvalue = 6.2'),
#  Text(0.9319727891156463, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 6.3'),
#  Text(0.9410430839002267, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 6.1'),
#  Text(0.9455782312925171, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 5.7'),
#  Text(0.9795918367346939, 0.5416666666666666, 'x[0] <= 1.095\nsquared_error = 2.946\nsamples = 9\nvalue = 3.278'),
#  Text(0.9682539682539683, 0.4583333333333333, 'x[0] <= 1.089\nsquared_error = 0.604\nsamples = 7\nvalue = 4.114'),
#  Text(0.9591836734693877, 0.375, 'x[2] <= 92.5\nsquared_error = 0.003\nsamples = 2\nvalue = 5.25'),
#  Text(0.9546485260770975, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 5.3'),
#  Text(0.963718820861678, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 5.2'),
#  Text(0.9773242630385488, 0.375, 'x[0] <= 1.092\nsquared_error = 0.122\nsamples = 5\nvalue = 3.66'),
#  Text(0.9727891156462585, 0.2916666666666667, 'x[0] <= 1.091\nsquared_error = 0.017\nsamples = 4\nvalue = 3.825'),
#  Text(0.9682539682539683, 0.20833333333333334, 'x[4] <= 51.25\nsquared_error = 0.002\nsamples = 2\nvalue = 3.95'),
#  Text(0.963718820861678, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.9727891156462585, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 3.9'),
#  Text(0.9773242630385488, 0.20833333333333334, 'squared_error = 0.0\nsamples = 2\nvalue = 3.7'),
#  Text(0.981859410430839, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.9909297052154195, 0.4583333333333333, 'x[4] <= 48.6\nsquared_error = 0.122\nsamples = 2\nvalue = 0.35'),
#  Text(0.9863945578231292, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.9954648526077098, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 0.7'),
#  Text(0.9574829931972789, 0.625, 'squared_error = -0.0\nsamples = 1\nvalue = 17.4')]

# %%
path = reg.cost_complexity_pruning_path(X_train, y_train)
ccp_alpha = path.ccp_alphas

# %%
alphalist = []
for i in range(len(ccp_alpha)):
    reg = DecisionTreeRegressor(ccp_alpha=ccp_alpha[i])
    reg.fit(X_train, y_train)
    alphalist.append(reg)

# %%
trainscore = [alphalist[i].score(X_train, y_train) for i in range(len(alphalist))]
testscore = [alphalist[i].score(X_test, y_test) for i in range(len(alphalist))]

plt.xlabel('alpha')
plt.ylabel('accuracy')
plt.plot(ccp_alpha, trainscore, marker='o', label='training', color='magenta', drawstyle='steps-post')
plt.plot(ccp_alpha, testscore, marker='+', label='testing', color='red', drawstyle='steps-post')
plt.legend()
plt.show()

# %%
## normal approach
clf = DecisionTreeRegressor(ccp_alpha=1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(f'Decision Tree Normal Approach : {metrics.r2_score(y_test, y_pred)}')

rf = RandomForestRegressor(n_estimators=1000, ccp_alpha=1)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print(f'Random Forest Normal Approach : {metrics.r2_score(y_test, y_pred_rf)}')
# Out:
# Decision Tree Normal Approach : 0.9411661375326366
# Random Forest Normal Approach : 0.9759565996080847

# %%
params = {
    'RandomForest': {
        'model': RandomForestRegressor(),
        'params': {
            'n_estimators': [int(x) for x in np.linspace(start=1, stop=1200, num=10)],
            'criterion': ["squared_error", "absolute_error"],  # updated
            'max_depth': [int(x) for x in np.linspace(start=1, stop=30, num=5)],
            'min_samples_split': [2, 5, 10, 12],
            'min_samples_leaf': [2, 5, 10, 12],
            'max_features': ['auto', 'sqrt'],
            'ccp_alpha': [1, 2, 2.5, 3, 3.5, 4, 5],
        },
    },
    'D-tree': {
        'model': DecisionTreeRegressor(),
        'params': {
            'criterion': ["squared_error", "absolute_error"],  # updated
            'splitter': ['best', 'random'],
            'min_samples_split': [1, 2, 5, 10, 12],
            'min_samples_leaf': [1, 2, 5, 10, 12],
            'max_features': ['auto', 'sqrt'],
            'ccp_alpha': [1, 2, 2.5, 3, 3.5, 4, 5],
        },
    },
    'SVM': {
        'model': SVR(),
        'params': {
            'C': [0.25, 0.50, 0.75, 1.0],
            'tol': [1e-10, 1e-5, 1e-4, 0.025, 0.50, 0.75],
            'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
            'max_iter': [int(x) for x in np.linspace(start=1, stop=250, num=10)],
        },
    },
}

# %%
scores = []
for modelname, mp in params.items():
    clf = RandomizedSearchCV(mp['model'], param_distributions=mp['params'],
                             cv=5, n_jobs=-1, n_iter=10, scoring='neg_mean_squared_error')

    clf.fit(X_train, y_train)
    scores.append({
        'model_name': modelname,
        'best_score': clf.best_score_,
        'best_estimator': clf.best_estimator_
    })
# Out:
# C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 30 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 23 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [ -9.96620388          nan          nan  -9.42651713          nan
#           nan          nan -74.36273092          nan -15.15001655]
#   warnings.warn(
# C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 40 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 28 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [         nan          nan          nan          nan          nan
#           nan          nan -32.86826524          nan -75.22691098]
#   warnings.warn(
# C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=111).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
scoresdf = pd.DataFrame(scores, columns=['model_name', 'best_score', 'best_estimator'])
scoresdf
# Out:
#      model_name  best_score                                     best_estimator
# 0  RandomForest   -9.426517  (DecisionTreeRegressor(ccp_alpha=3.5, max_dept...
# 1        D-tree  -32.868265  DecisionTreeRegressor(ccp_alpha=2, criterion='...
# 2           SVM  -36.132544  SVR(C=0.5, kernel='poly', max_iter=111, tol=1e...

# %%
scores[0]['best_estimator']
# Out:
# RandomForestRegressor(ccp_alpha=3.5, max_depth=30, max_features='sqrt',
#                       min_samples_leaf=10, min_samples_split=10,
#                       n_estimators=1066)

# %%
rf = RandomForestRegressor(n_estimators=1000, ccp_alpha=1)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

print(metrics.r2_score(y_test, y_pred))
# Out:
# 0.9755679156200925

# %%
# Create a copy of totrain without the 'Actual Result' and 'Predicted Result'
features = totrain.drop(columns=['Actual Result', 'Predicted Result'], errors='ignore')

predicted = []
for i in range(len(features)):
    predicted.append(rf.predict(features.iloc[[i]]))  # Use the DataFrame with original feature names

totrain['Actual Result'] = test
totrain['Predicted Result'] = np.array(predicted)
totrain
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\2858122874.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totrain['Actual Result'] = test
# C:\Users\shubh\AppData\Local\Temp\ipykernel_17808\2858122874.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totrain['Predicted Result'] = np.array(predicted)
#      Density  Abdomen  Chest    Hip  Thigh  Actual Result  Predicted Result
# 0     1.0708     85.2   93.1   94.5   59.0           12.3         11.783390
# 1     1.0853     83.0   93.6   98.7   58.7            6.1          6.566257
# 2     1.0414     87.9   95.8   99.2   59.6           25.3         24.892755
# 3     1.0751     86.4  101.8  101.2   60.1           10.4         10.520230
# 4     1.0340    100.0   97.3  101.9   63.2           28.7         30.345920
# ..       ...      ...    ...    ...    ...            ...               ...
# 247   1.0736     83.6   89.2   88.8   49.6           11.0         10.579555
# 248   1.0236    105.0  108.5  104.5   59.6           33.6         31.876240
# 249   1.0328    111.5  111.1  101.7   60.3           29.3         30.730826
# 250   1.0399    101.3  108.3   97.8   56.0           26.0         25.071228
# 251   1.0271    108.5  112.4  107.1   59.3           31.9         31.553108
#
# [252 rows x 7 columns]

# %%
sn.kdeplot(totrain['Actual Result'], label='Actual Result', color='magenta')
sn.kdeplot(totrain['Predicted Result'], label='Predicted Result', color='red')
plt.legend()
plt.show()

# %%
sn.kdeplot(totrain['Actual Result'], label='Actual Result', color='magenta')
sn.kdeplot(totrain['Predicted Result'], label='Predicted Result', color='red')
plt.legend()
plt.show()

# %%
# saving the model
import pickle
rf = RandomForestClassifier() 
file = open('bodyfatmodel2.pkl', 'wb')
pickle.dump(rf, file)
file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 import pickle
#       3 file = open('bodyfatmodel2.pkl', 'wb')
# ----> 4 pickle.dump(rf, file)
#       5 file.close()
#
# NameError: name 'rf' is not defined
