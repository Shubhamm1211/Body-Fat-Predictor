# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('bodyfat.csv')
df.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
def plotdistplots(col):
    plt.figure(figsize=(12,5))
    sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
    sn.distplot(df[col], color = 'red', hist=False, label=col)
    plt.legend()
    plt.show()

cols = list(df.columns)
for i in cols:
    print(f'Distribution plots for {i} feature is shown ')
    plotdistplots(i)
    print("-"*100)
# Out:
# Distribution plots for Density feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for BodyFat feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Age feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Weight feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Height feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Neck feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Chest feature is shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Abdomen feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Hip feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Thigh feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Knee feature is shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Ankle feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Biceps feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Forearm feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='BodyFat')
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Wrist feature is shown
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\1373124706.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color = 'red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------

# %%
import scipy.stats as stats

# %%
def drawplots(df, col):
    plt.figure(figsize=(15,7))
    plt.subplot(1,3,1)
    plt.hist(df[col],color='magenta')

    plt.subplot(1,3,2)
    stats.probplot(df[col], dist='norm', plot=plt)

    plt.subplot(1,3,3)
    sn.boxplot(df[col],color='magenta')

    plt.show()

cols = list(df.columns)
for i in range(len(cols)):
    print(f'Distribution plots for the feature {cols[i]} are shown ⬇')
    drawplots(df, cols[i])
    print("="*100)
# Out:
# Distribution plots for the feature Density are shown ⬇
# ====================================================================================================
# Distribution plots for the feature BodyFat are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Age are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Weight are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Height are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Neck are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Chest are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Abdomen are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Hip are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Thigh are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Knee are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Ankle are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Biceps are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Forearm are shown ⬇
# ====================================================================================================
# Distribution plots for the feature Wrist are shown ⬇
# ====================================================================================================

# %%
upperlimit = []
lowerlimit = []
for i in df.columns:
    upperlimit.append(df[i].mean()+(df[i].std())*4)
    lowerlimit.append(df[i].mean()-(df[i].std())*4)

# %%
cols = list(df.columns)
j = 0
for i in range(len(cols)):
    temp = df.loc[(df[cols[i]] > upperlimit[j]) & (df[cols[i]] < lowerlimit[j])]
    j += 1

# %%
temp
# Out:
# Empty DataFrame
# Columns: [Density, BodyFat, Age, Weight, Height, Neck, Chest, Abdomen, Hip, Thigh, Knee, Ankle, Biceps, Forearm, Wrist]
# Index: []

# %%
data = df.copy()
test = data['BodyFat']
train = data.drop(['BodyFat'],axis=1)

# %%
from sklearn.ensemble import ExtraTreesRegressor
er = ExtraTreesRegressor()
er.fit(train,test)
# Out:
# ExtraTreesRegressor()

# %%
series = pd.Series(er.feature_importances_, index=train.columns)
series.nlargest(5).plot(kind='barh', color='green')
# Out:
# <Axes: >

# %%
from sklearn.feature_selection import mutual_info_regression
mr = mutual_info_regression(train, test)

# %%
plotdata = pd.Series(mr, index=train.columns)
plotdata.nlargest(5).plot(kind='barh', color='green')
# Out:
# <Axes: >

# %%
data
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %%
plt.figure(figsize=(15,7))
sn.heatmap(df.corr(), annot=True, cmap='plasma')
# Out:
# <Axes: >

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]>

# %%
def correlation(df, threshold):
    colcor = set()
    
    cormat = df.corr()
    for i in range(len(cormat)):
        for j in range(i):
            '''
            for each cell get the value of that cell by .iloc[i][j],
            where i is the row and j is the col if that abs(value) is greater
            than the threshold, get the col_name and add it in the set
            '''
            if abs(cormat.iloc[i, j]) > threshold:
                colname = cormat.columns[i]
                colcor.add(colname)
    
    return colcor

ans = correlation(train, threshold=0.85)
ans
# Out:
# {'Abdomen', 'Chest', 'Hip', 'Knee', 'Thigh'}

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
temp = data[list(data.columns)]
info = pd.DataFrame()
info['VIF'] = [variance_inflation_factor(temp.values, i) for i in range(temp.shape[1])]
info['Column'] = temp.columns
info
# Out:
#             VIF   Column
# 0   3695.622377  Density
# 1     33.845429  BodyFat
# 2     31.376101      Age
# 3   1238.097164   Weight
# 4    613.410514   Height
# 5   1081.965633     Neck
# 6   1374.457425    Chest
# 7   1332.624257  Abdomen
# 8   2933.636131      Hip
# 9   1017.257501    Thigh
# 10  1187.890413     Knee
# 11   356.293529    Ankle
# 12   419.391664   Biceps
# 13   454.571766  Forearm
# 14  1349.973920    Wrist

# %%
cols1 = list(series.nlargest(5).index)
cols2 = list(plotdata.nlargest(5).index)

cols1, cols2
# Out:
# (['Density', 'Abdomen', 'Chest', 'Weight', 'Hip'],
#  ['Density', 'Abdomen', 'Chest', 'Hip', 'Thigh'])

# %%
totrain = train[cols1]
totrain.head()
# Out:
#    Density  Abdomen  Chest  Weight    Hip
# 0   1.0708     85.2   93.1  154.25   94.5
# 1   1.0853     83.0   93.6  173.25   98.7
# 2   1.0414     87.9   95.8  154.00   99.2
# 3   1.0751     86.4  101.8  184.75  101.2
# 4   1.0340    100.0   97.3  184.25  101.9

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn import metrics
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %%
X_train, X_test, y_train, y_test = train_test_split(totrain, test, test_size=0.2)
X_train.shape, X_test.shape
# Out:
# ((201, 5), (51, 5))

# %%
reg = DecisionTreeRegressor()
reg.fit(X_train, y_train)
plt.figure(figsize=(15,7))
tree.plot_tree(reg, filled=True)
# Out:
# [Text(0.48795103092783504, 0.9545454545454546, 'x[0] <= 1.055\nsquared_error = 74.386\nsamples = 201\nvalue = 19.324'),
#  Text(0.1949742268041237, 0.8636363636363636, 'x[0] <= 1.036\nsquared_error = 27.467\nsamples = 103\nvalue = 26.231'),
#  Text(0.3414626288659794, 0.9090909090909092, 'True  '),
#  Text(0.055927835051546394, 0.7727272727272727, 'x[0] <= 1.016\nsquared_error = 14.4\nsamples = 35\nvalue = 32.231'),
#  Text(0.008247422680412371, 0.6818181818181818, 'x[0] <= 1.003\nsquared_error = 16.347\nsamples = 3\nvalue = 41.9'),
#  Text(0.004123711340206186, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 47.5'),
#  Text(0.012371134020618556, 0.5909090909090909, 'x[3] <= 218.0\nsquared_error = 1.0\nsamples = 2\nvalue = 39.1'),
#  Text(0.008247422680412371, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 40.1'),
#  Text(0.016494845360824743, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 38.1'),
#  Text(0.10360824742268042, 0.6818181818181818, 'x[0] <= 1.029\nsquared_error = 4.632\nsamples = 32\nvalue = 31.325'),
#  Text(0.05463917525773196, 0.5909090909090909, 'x[0] <= 1.024\nsquared_error = 1.635\nsamples = 18\nvalue = 32.95'),
#  Text(0.024742268041237112, 0.5, 'x[2] <= 117.25\nsquared_error = 0.276\nsamples = 6\nvalue = 34.567'),
#  Text(0.01443298969072165, 0.4090909090909091, 'x[0] <= 1.021\nsquared_error = 0.122\nsamples = 2\nvalue = 33.95'),
#  Text(0.010309278350515464, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 34.3'),
#  Text(0.018556701030927835, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 33.6'),
#  Text(0.03505154639175258, 0.4090909090909091, 'x[0] <= 1.021\nsquared_error = 0.067\nsamples = 4\nvalue = 34.875'),
#  Text(0.026804123711340205, 0.3181818181818182, 'x[3] <= 293.825\nsquared_error = 0.01\nsamples = 2\nvalue = 35.1'),
#  Text(0.02268041237113402, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 35.0'),
#  Text(0.030927835051546393, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 35.2'),
#  Text(0.04329896907216495, 0.3181818181818182, 'x[0] <= 1.021\nsquared_error = 0.023\nsamples = 2\nvalue = 34.65'),
#  Text(0.03917525773195876, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 34.8'),
#  Text(0.04742268041237113, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 34.5'),
#  Text(0.08453608247422681, 0.5, 'x[0] <= 1.027\nsquared_error = 0.354\nsamples = 12\nvalue = 32.142'),
#  Text(0.06804123711340206, 0.4090909090909091, 'x[0] <= 1.025\nsquared_error = 0.045\nsamples = 6\nvalue = 32.683'),
#  Text(0.05979381443298969, 0.3181818181818182, 'x[0] <= 1.025\nsquared_error = 0.002\nsamples = 3\nvalue = 32.867'),
#  Text(0.05567010309278351, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 32.9'),
#  Text(0.06391752577319587, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 32.8'),
#  Text(0.07628865979381444, 0.3181818181818182, 'x[1] <= 106.8\nsquared_error = 0.02\nsamples = 3\nvalue = 32.5'),
#  Text(0.07216494845360824, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 32.3'),
#  Text(0.08041237113402062, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 32.6'),
#  Text(0.10103092783505155, 0.4090909090909091, 'x[0] <= 1.027\nsquared_error = 0.077\nsamples = 6\nvalue = 31.6'),
#  Text(0.09278350515463918, 0.3181818181818182, 'x[4] <= 106.55\nsquared_error = 0.002\nsamples = 2\nvalue = 31.95'),
#  Text(0.088659793814433, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 32.0'),
#  Text(0.09690721649484536, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 31.9'),
#  Text(0.10927835051546392, 0.3181818181818182, 'x[0] <= 1.029\nsquared_error = 0.022\nsamples = 4\nvalue = 31.425'),
#  Text(0.10515463917525773, 0.22727272727272727, 'x[0] <= 1.028\nsquared_error = 0.007\nsamples = 3\nvalue = 31.5'),
#  Text(0.10103092783505155, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 31.6'),
#  Text(0.10927835051546392, 0.13636363636363635, 'x[3] <= 183.125\nsquared_error = 0.003\nsamples = 2\nvalue = 31.45'),
#  Text(0.10515463917525773, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 31.4'),
#  Text(0.1134020618556701, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 31.5'),
#  Text(0.1134020618556701, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 31.2'),
#  Text(0.15257731958762888, 0.5909090909090909, 'x[0] <= 1.033\nsquared_error = 0.727\nsamples = 14\nvalue = 29.236'),
#  Text(0.13402061855670103, 0.5, 'x[0] <= 1.032\nsquared_error = 0.179\nsamples = 8\nvalue = 29.875'),
#  Text(0.12164948453608247, 0.4090909090909091, 'x[0] <= 1.03\nsquared_error = 0.09\nsamples = 5\nvalue = 30.14'),
#  Text(0.11752577319587629, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 30.7'),
#  Text(0.12577319587628866, 0.3181818181818182, 'x[0] <= 1.031\nsquared_error = 0.015\nsamples = 4\nvalue = 30.0'),
#  Text(0.12164948453608247, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 30.2'),
#  Text(0.12989690721649486, 0.22727272727272727, 'x[2] <= 104.7\nsquared_error = 0.002\nsamples = 3\nvalue = 29.933'),
#  Text(0.12577319587628866, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 30.0'),
#  Text(0.13402061855670103, 0.13636363636363635, 'squared_error = -0.0\nsamples = 2\nvalue = 29.9'),
#  Text(0.1463917525773196, 0.4090909090909091, 'x[4] <= 103.95\nsquared_error = 0.016\nsamples = 3\nvalue = 29.433'),
#  Text(0.1422680412371134, 0.3181818181818182, 'x[4] <= 101.15\nsquared_error = 0.003\nsamples = 2\nvalue = 29.35'),
#  Text(0.13814432989690723, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 29.4'),
#  Text(0.1463917525773196, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 29.3'),
#  Text(0.15051546391752577, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 29.6'),
#  Text(0.1711340206185567, 0.5, 'x[0] <= 1.035\nsquared_error = 0.185\nsamples = 6\nvalue = 28.383'),
#  Text(0.16288659793814433, 0.4090909090909091, 'x[2] <= 112.75\nsquared_error = 0.02\nsamples = 3\nvalue = 28.8'),
#  Text(0.15876288659793814, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 28.7'),
#  Text(0.1670103092783505, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 29.0'),
#  Text(0.17938144329896907, 0.4090909090909091, 'x[1] <= 101.7\nsquared_error = 0.002\nsamples = 3\nvalue = 27.967'),
#  Text(0.17525773195876287, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 27.9'),
#  Text(0.18350515463917524, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 28.0'),
#  Text(0.334020618556701, 0.7727272727272727, 'x[0] <= 1.047\nsquared_error = 6.123\nsamples = 68\nvalue = 23.143'),
#  Text(0.2551546391752577, 0.6818181818181818, 'x[0] <= 1.041\nsquared_error = 1.467\nsamples = 31\nvalue = 25.532'),
#  Text(0.22164948453608246, 0.5909090909090909, 'x[0] <= 1.039\nsquared_error = 0.272\nsamples = 15\nvalue = 26.62'),
#  Text(0.21030927835051547, 0.5, 'x[0] <= 1.038\nsquared_error = 0.054\nsamples = 10\nvalue = 26.96'),
#  Text(0.2, 0.4090909090909091, 'x[0] <= 1.037\nsquared_error = 0.012\nsamples = 6\nvalue = 27.133'),
#  Text(0.19175257731958764, 0.3181818181818182, 'x[0] <= 1.037\nsquared_error = 0.002\nsamples = 3\nvalue = 27.233'),
#  Text(0.18762886597938144, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 27.3'),
#  Text(0.1958762886597938, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 27.2'),
#  Text(0.20824742268041238, 0.3181818181818182, 'x[2] <= 103.2\nsquared_error = 0.002\nsamples = 3\nvalue = 27.033'),
#  Text(0.20412371134020618, 0.22727272727272727, 'x[2] <= 101.6\nsquared_error = 0.0\nsamples = 2\nvalue = 27.0'),
#  Text(0.2, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.20824742268041238, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.21237113402061855, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 27.1'),
#  Text(0.22061855670103092, 0.4090909090909091, 'x[1] <= 90.7\nsquared_error = 0.005\nsamples = 4\nvalue = 26.7'),
#  Text(0.21649484536082475, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 26.8'),
#  Text(0.22474226804123712, 0.3181818181818182, 'x[2] <= 104.6\nsquared_error = 0.002\nsamples = 3\nvalue = 26.667'),
#  Text(0.22061855670103092, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 26.7'),
#  Text(0.2288659793814433, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 26.6'),
#  Text(0.2329896907216495, 0.5, 'x[1] <= 97.3\nsquared_error = 0.014\nsamples = 5\nvalue = 25.94'),
#  Text(0.2288659793814433, 0.4090909090909091, 'squared_error = 0.0\nsamples = 2\nvalue = 25.8'),
#  Text(0.23711340206185566, 0.4090909090909091, 'x[0] <= 1.04\nsquared_error = 0.002\nsamples = 3\nvalue = 26.033'),
#  Text(0.2329896907216495, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 26.1'),
#  Text(0.24123711340206186, 0.3181818181818182, 'x[2] <= 114.1\nsquared_error = 0.0\nsamples = 2\nvalue = 26.0'),
#  Text(0.23711340206185566, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 26.0'),
#  Text(0.24536082474226803, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 26.0'),
#  Text(0.28865979381443296, 0.5909090909090909, 'x[0] <= 1.045\nsquared_error = 0.437\nsamples = 16\nvalue = 24.512'),
#  Text(0.27010309278350514, 0.5, 'x[0] <= 1.042\nsquared_error = 0.144\nsamples = 12\nvalue = 24.842'),
#  Text(0.2536082474226804, 0.4090909090909091, 'x[1] <= 96.65\nsquared_error = 0.015\nsamples = 4\nvalue = 25.3'),
#  Text(0.24948453608247423, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 25.5'),
#  Text(0.25773195876288657, 0.3181818181818182, 'x[3] <= 191.875\nsquared_error = 0.002\nsamples = 3\nvalue = 25.233'),
#  Text(0.2536082474226804, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 25.3'),
#  Text(0.2618556701030928, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 25.2'),
#  Text(0.2865979381443299, 0.4090909090909091, 'x[0] <= 1.043\nsquared_error = 0.051\nsamples = 8\nvalue = 24.612'),
#  Text(0.27422680412371137, 0.3181818181818182, 'x[1] <= 97.85\nsquared_error = 0.007\nsamples = 4\nvalue = 24.825'),
#  Text(0.27010309278350514, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 24.9'),
#  Text(0.27835051546391754, 0.22727272727272727, 'x[2] <= 105.35\nsquared_error = 0.002\nsamples = 2\nvalue = 24.75'),
#  Text(0.27422680412371137, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.2824742268041237, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 24.7'),
#  Text(0.29896907216494845, 0.3181818181818182, 'x[4] <= 104.05\nsquared_error = 0.005\nsamples = 4\nvalue = 24.4'),
#  Text(0.2948453608247423, 0.22727272727272727, 'x[2] <= 98.0\nsquared_error = 0.002\nsamples = 3\nvalue = 24.367'),
#  Text(0.2907216494845361, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.29896907216494845, 0.13636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 24.4'),
#  Text(0.3030927835051546, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.30721649484536084, 0.5, 'x[2] <= 103.15\nsquared_error = 0.017\nsamples = 4\nvalue = 23.525'),
#  Text(0.3030927835051546, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.311340206185567, 0.4090909090909091, 'x[3] <= 183.875\nsquared_error = 0.0\nsamples = 3\nvalue = 23.6'),
#  Text(0.30721649484536084, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 23.6'),
#  Text(0.3154639175257732, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 23.6'),
#  Text(0.4128865979381443, 0.6818181818181818, 'x[0] <= 1.051\nsquared_error = 1.231\nsamples = 37\nvalue = 21.141'),
#  Text(0.36391752577319586, 0.5909090909090909, 'x[0] <= 1.049\nsquared_error = 0.338\nsamples = 19\nvalue = 22.068'),
#  Text(0.3422680412371134, 0.5, 'x[0] <= 1.047\nsquared_error = 0.082\nsamples = 12\nvalue = 22.467'),
#  Text(0.32783505154639175, 0.4090909090909091, 'x[0] <= 1.047\nsquared_error = 0.007\nsamples = 4\nvalue = 22.825'),
#  Text(0.3237113402061856, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 22.9'),
#  Text(0.3319587628865979, 0.3181818181818182, 'x[1] <= 87.95\nsquared_error = 0.002\nsamples = 2\nvalue = 22.75'),
#  Text(0.32783505154639175, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.33608247422680415, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 22.7'),
#  Text(0.35670103092783506, 0.4090909090909091, 'x[1] <= 93.35\nsquared_error = 0.024\nsamples = 8\nvalue = 22.287'),
#  Text(0.34845360824742266, 0.3181818181818182, 'x[0] <= 1.048\nsquared_error = 0.002\nsamples = 3\nvalue = 22.467'),
#  Text(0.3443298969072165, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 22.5'),
#  Text(0.3525773195876289, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 22.4'),
#  Text(0.3649484536082474, 0.3181818181818182, 'x[2] <= 101.65\nsquared_error = 0.006\nsamples = 5\nvalue = 22.18'),
#  Text(0.36082474226804123, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 22.1'),
#  Text(0.36907216494845363, 0.22727272727272727, 'x[0] <= 1.048\nsquared_error = 0.002\nsamples = 3\nvalue = 22.233'),
#  Text(0.3649484536082474, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 22.3'),
#  Text(0.3731958762886598, 0.13636363636363635, 'squared_error = -0.0\nsamples = 2\nvalue = 22.2'),
#  Text(0.38556701030927837, 0.5, 'x[0] <= 1.05\nsquared_error = 0.038\nsamples = 7\nvalue = 21.386'),
#  Text(0.38144329896907214, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 21.8'),
#  Text(0.38969072164948454, 0.4090909090909091, 'x[0] <= 1.05\nsquared_error = 0.011\nsamples = 6\nvalue = 21.317'),
#  Text(0.38144329896907214, 0.3181818181818182, 'x[1] <= 88.1\nsquared_error = 0.002\nsamples = 2\nvalue = 21.45'),
#  Text(0.37731958762886597, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 21.5'),
#  Text(0.38556701030927837, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 21.4'),
#  Text(0.3979381443298969, 0.3181818181818182, 'x[0] <= 1.05\nsquared_error = 0.002\nsamples = 4\nvalue = 21.25'),
#  Text(0.3938144329896907, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 21.3'),
#  Text(0.4020618556701031, 0.22727272727272727, 'x[0] <= 1.051\nsquared_error = 0.0\nsamples = 2\nvalue = 21.2'),
#  Text(0.3979381443298969, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.4061855670103093, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.4618556701030928, 0.5909090909090909, 'x[0] <= 1.053\nsquared_error = 0.306\nsamples = 18\nvalue = 20.161'),
#  Text(0.43917525773195876, 0.5, 'x[0] <= 1.052\nsquared_error = 0.082\nsamples = 12\nvalue = 20.508'),
#  Text(0.422680412371134, 0.4090909090909091, 'x[0] <= 1.051\nsquared_error = 0.007\nsamples = 4\nvalue = 20.875'),
#  Text(0.4144329896907217, 0.3181818181818182, 'x[0] <= 1.051\nsquared_error = 0.002\nsamples = 2\nvalue = 20.95'),
#  Text(0.41030927835051545, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.41855670103092785, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.4309278350515464, 0.3181818181818182, 'x[3] <= 186.375\nsquared_error = 0.0\nsamples = 2\nvalue = 20.8'),
#  Text(0.4268041237113402, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(0.4350515463917526, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(0.4556701030927835, 0.4090909090909091, 'x[0] <= 1.053\nsquared_error = 0.019\nsamples = 8\nvalue = 20.325'),
#  Text(0.44742268041237115, 0.3181818181818182, 'x[3] <= 218.75\nsquared_error = 0.003\nsamples = 6\nvalue = 20.4'),
#  Text(0.44329896907216493, 0.22727272727272727, 'x[1] <= 91.15\nsquared_error = 0.002\nsamples = 5\nvalue = 20.42'),
#  Text(0.43917525773195876, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 20.5'),
#  Text(0.44742268041237115, 0.13636363636363635, 'squared_error = 0.0\nsamples = 4\nvalue = 20.4'),
#  Text(0.4515463917525773, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.4639175257731959, 0.3181818181818182, 'x[1] <= 89.6\nsquared_error = 0.0\nsamples = 2\nvalue = 20.1'),
#  Text(0.45979381443298967, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.1'),
#  Text(0.46804123711340206, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.1'),
#  Text(0.4845360824742268, 0.5, 'x[0] <= 1.054\nsquared_error = 0.029\nsamples = 6\nvalue = 19.467'),
#  Text(0.4762886597938144, 0.4090909090909091, 'x[4] <= 99.2\nsquared_error = 0.007\nsamples = 4\nvalue = 19.575'),
#  Text(0.47216494845360824, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 19.5'),
#  Text(0.48041237113402063, 0.3181818181818182, 'x[3] <= 206.25\nsquared_error = 0.002\nsamples = 2\nvalue = 19.65'),
#  Text(0.4762886597938144, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 19.7'),
#  Text(0.4845360824742268, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.4927835051546392, 0.4090909090909091, 'x[0] <= 1.055\nsquared_error = 0.003\nsamples = 2\nvalue = 19.25'),
#  Text(0.488659793814433, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.49690721649484537, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 19.2'),
#  Text(0.7809278350515464, 0.8636363636363636, 'x[0] <= 1.073\nsquared_error = 20.867\nsamples = 98\nvalue = 12.065'),
#  Text(0.6344394329896907, 0.9090909090909092, '  False'),
#  Text(0.6445876288659794, 0.7727272727272727, 'x[0] <= 1.065\nsquared_error = 6.637\nsamples = 61\nvalue = 14.97'),
#  Text(0.5809278350515464, 0.6818181818181818, 'x[0] <= 1.06\nsquared_error = 1.224\nsamples = 30\nvalue = 17.013'),
#  Text(0.545360824742268, 0.5909090909090909, 'x[0] <= 1.058\nsquared_error = 0.219\nsamples = 14\nvalue = 18.029'),
#  Text(0.5237113402061856, 0.5, 'x[0] <= 1.057\nsquared_error = 0.079\nsamples = 8\nvalue = 18.375'),
#  Text(0.5092783505154639, 0.4090909090909091, 'x[0] <= 1.056\nsquared_error = 0.007\nsamples = 3\nvalue = 18.7'),
#  Text(0.5051546391752577, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 18.8'),
#  Text(0.51340206185567, 0.3181818181818182, 'x[1] <= 96.6\nsquared_error = 0.003\nsamples = 2\nvalue = 18.65'),
#  Text(0.5092783505154639, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 18.6'),
#  Text(0.5175257731958763, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 18.7'),
#  Text(0.5381443298969072, 0.4090909090909091, 'x[1] <= 93.95\nsquared_error = 0.022\nsamples = 5\nvalue = 18.18'),
#  Text(0.5298969072164949, 0.3181818181818182, 'x[3] <= 168.625\nsquared_error = 0.002\nsamples = 3\nvalue = 18.067'),
#  Text(0.5257731958762887, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 18.0'),
#  Text(0.534020618556701, 0.22727272727272727, 'x[4] <= 98.4\nsquared_error = 0.0\nsamples = 2\nvalue = 18.1'),
#  Text(0.5298969072164949, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 18.1'),
#  Text(0.5381443298969072, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 18.1'),
#  Text(0.5463917525773195, 0.3181818181818182, 'x[2] <= 106.55\nsquared_error = 0.002\nsamples = 2\nvalue = 18.35'),
#  Text(0.5422680412371134, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 18.4'),
#  Text(0.5505154639175258, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 18.3'),
#  Text(0.5670103092783505, 0.5, 'x[2] <= 95.5\nsquared_error = 0.032\nsamples = 6\nvalue = 17.567'),
#  Text(0.5587628865979382, 0.4090909090909091, 'x[0] <= 1.058\nsquared_error = 0.002\nsamples = 3\nvalue = 17.733'),
#  Text(0.554639175257732, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 17.8'),
#  Text(0.5628865979381443, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 17.7'),
#  Text(0.5752577319587628, 0.4090909090909091, 'x[0] <= 1.059\nsquared_error = 0.007\nsamples = 3\nvalue = 17.4'),
#  Text(0.5711340206185567, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 17.5'),
#  Text(0.5793814432989691, 0.3181818181818182, 'x[1] <= 83.35\nsquared_error = 0.003\nsamples = 2\nvalue = 17.35'),
#  Text(0.5752577319587628, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 17.4'),
#  Text(0.5835051546391753, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 17.3'),
#  Text(0.6164948453608248, 0.5909090909090909, 'x[0] <= 1.062\nsquared_error = 0.412\nsamples = 16\nvalue = 16.125'),
#  Text(0.6, 0.5, 'x[0] <= 1.061\nsquared_error = 0.037\nsamples = 8\nvalue = 16.7'),
#  Text(0.5917525773195876, 0.4090909090909091, 'x[3] <= 172.0\nsquared_error = 0.002\nsamples = 3\nvalue = 16.933'),
#  Text(0.5876288659793815, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 17.0'),
#  Text(0.5958762886597938, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 16.9'),
#  Text(0.6082474226804123, 0.4090909090909091, 'x[0] <= 1.061\nsquared_error = 0.006\nsamples = 5\nvalue = 16.56'),
#  Text(0.6041237113402061, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 16.7'),
#  Text(0.6123711340206186, 0.3181818181818182, 'x[3] <= 190.75\nsquared_error = 0.002\nsamples = 4\nvalue = 16.525'),
#  Text(0.6082474226804123, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 16.5'),
#  Text(0.6164948453608248, 0.22727272727272727, 'x[3] <= 210.25\nsquared_error = 0.003\nsamples = 2\nvalue = 16.55'),
#  Text(0.6123711340206186, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 16.6'),
#  Text(0.6206185567010309, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 16.5'),
#  Text(0.6329896907216495, 0.5, 'x[0] <= 1.063\nsquared_error = 0.125\nsamples = 8\nvalue = 15.55'),
#  Text(0.6247422680412371, 0.4090909090909091, 'x[4] <= 94.9\nsquared_error = 0.027\nsamples = 4\nvalue = 15.875'),
#  Text(0.6206185567010309, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 15.6'),
#  Text(0.6288659793814433, 0.3181818181818182, 'x[3] <= 188.625\nsquared_error = 0.002\nsamples = 3\nvalue = 15.967'),
#  Text(0.6247422680412371, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 16.0'),
#  Text(0.6329896907216495, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 15.9'),
#  Text(0.6412371134020619, 0.4090909090909091, 'x[0] <= 1.064\nsquared_error = 0.012\nsamples = 4\nvalue = 15.225'),
#  Text(0.6371134020618556, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 15.4'),
#  Text(0.6453608247422681, 0.3181818181818182, 'x[0] <= 1.064\nsquared_error = 0.002\nsamples = 3\nvalue = 15.167'),
#  Text(0.6412371134020619, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 15.2'),
#  Text(0.6494845360824743, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 15.1'),
#  Text(0.7082474226804124, 0.6818181818181818, 'x[0] <= 1.07\nsquared_error = 3.928\nsamples = 31\nvalue = 12.994'),
#  Text(0.668041237113402, 0.5909090909090909, 'x[2] <= 90.0\nsquared_error = 5.626\nsamples = 17\nvalue = 13.788'),
#  Text(0.6536082474226804, 0.5, 'x[0] <= 1.067\nsquared_error = 15.602\nsamples = 2\nvalue = 9.55'),
#  Text(0.6494845360824743, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 5.6'),
#  Text(0.6577319587628866, 0.4090909090909091, 'squared_error = -0.0\nsamples = 1\nvalue = 13.5'),
#  Text(0.6824742268041237, 0.5, 'x[0] <= 1.067\nsquared_error = 1.581\nsamples = 15\nvalue = 14.353'),
#  Text(0.6659793814432989, 0.4090909090909091, 'x[2] <= 93.9\nsquared_error = 1.864\nsamples = 7\nvalue = 15.214'),
#  Text(0.6618556701030928, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.6701030927835051, 0.3181818181818182, 'x[0] <= 1.066\nsquared_error = 0.076\nsamples = 6\nvalue = 14.667'),
#  Text(0.6659793814432989, 0.22727272727272727, 'x[0] <= 1.065\nsquared_error = 0.014\nsamples = 5\nvalue = 14.78'),
#  Text(0.6577319587628866, 0.13636363636363635, 'x[0] <= 1.065\nsquared_error = 0.002\nsamples = 3\nvalue = 14.867'),
#  Text(0.6536082474226804, 0.045454545454545456, 'squared_error = 0.0\nsamples = 2\nvalue = 14.9'),
#  Text(0.6618556701030928, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 14.8'),
#  Text(0.6742268041237114, 0.13636363636363635, 'x[3] <= 178.125\nsquared_error = 0.002\nsamples = 2\nvalue = 14.65'),
#  Text(0.6701030927835051, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 14.7'),
#  Text(0.6783505154639176, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 14.6'),
#  Text(0.6742268041237114, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 14.1'),
#  Text(0.6989690721649484, 0.4090909090909091, 'x[0] <= 1.068\nsquared_error = 0.117\nsamples = 8\nvalue = 13.6'),
#  Text(0.6907216494845361, 0.3181818181818182, 'x[0] <= 1.068\nsquared_error = 0.021\nsamples = 6\nvalue = 13.783'),
#  Text(0.6865979381443299, 0.22727272727272727, 'x[4] <= 94.9\nsquared_error = 0.007\nsamples = 4\nvalue = 13.875'),
#  Text(0.6824742268041237, 0.13636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 13.8'),
#  Text(0.6907216494845361, 0.13636363636363635, 'x[4] <= 96.5\nsquared_error = 0.003\nsamples = 2\nvalue = 13.95'),
#  Text(0.6865979381443299, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 14.0'),
#  Text(0.6948453608247422, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 13.9'),
#  Text(0.6948453608247422, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 13.6'),
#  Text(0.7072164948453609, 0.3181818181818182, 'x[3] <= 167.625\nsquared_error = 0.003\nsamples = 2\nvalue = 13.05'),
#  Text(0.7030927835051546, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 13.1'),
#  Text(0.711340206185567, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 13.0'),
#  Text(0.7484536082474227, 0.5909090909090909, 'x[0] <= 1.071\nsquared_error = 0.168\nsamples = 14\nvalue = 12.029'),
#  Text(0.7278350515463917, 0.5, 'x[0] <= 1.071\nsquared_error = 0.018\nsamples = 8\nvalue = 12.35'),
#  Text(0.7195876288659794, 0.4090909090909091, 'x[4] <= 92.15\nsquared_error = 0.002\nsamples = 5\nvalue = 12.44'),
#  Text(0.7154639175257732, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 12.5'),
#  Text(0.7237113402061855, 0.3181818181818182, 'x[2] <= 97.4\nsquared_error = 0.0\nsamples = 3\nvalue = 12.4'),
#  Text(0.7195876288659794, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(0.7278350515463917, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 12.4'),
#  Text(0.7360824742268042, 0.4090909090909091, 'x[4] <= 95.3\nsquared_error = 0.007\nsamples = 3\nvalue = 12.2'),
#  Text(0.7319587628865979, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 12.3'),
#  Text(0.7402061855670103, 0.3181818181818182, 'x[3] <= 168.75\nsquared_error = 0.003\nsamples = 2\nvalue = 12.15'),
#  Text(0.7360824742268042, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 12.1'),
#  Text(0.7443298969072165, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 12.2'),
#  Text(0.7690721649484537, 0.5, 'x[0] <= 1.072\nsquared_error = 0.047\nsamples = 6\nvalue = 11.6'),
#  Text(0.7608247422680412, 0.4090909090909091, 'x[4] <= 101.95\nsquared_error = 0.007\nsamples = 3\nvalue = 11.8'),
#  Text(0.756701030927835, 0.3181818181818182, 'x[0] <= 1.072\nsquared_error = 0.003\nsamples = 2\nvalue = 11.85'),
#  Text(0.7525773195876289, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.9'),
#  Text(0.7608247422680412, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.7649484536082474, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.7'),
#  Text(0.777319587628866, 0.4090909090909091, 'x[3] <= 157.75\nsquared_error = 0.007\nsamples = 3\nvalue = 11.4'),
#  Text(0.7731958762886598, 0.3181818181818182, 'x[2] <= 93.45\nsquared_error = 0.002\nsamples = 2\nvalue = 11.45'),
#  Text(0.7690721649484537, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.4'),
#  Text(0.777319587628866, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.5'),
#  Text(0.7814432989690722, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 11.3'),
#  Text(0.9172680412371134, 0.7727272727272727, 'x[0] <= 1.084\nsquared_error = 7.474\nsamples = 37\nvalue = 7.276'),
#  Text(0.8582474226804123, 0.6818181818181818, 'x[0] <= 1.078\nsquared_error = 1.603\nsamples = 25\nvalue = 8.852'),
#  Text(0.8237113402061855, 0.5909090909090909, 'x[0] <= 1.076\nsquared_error = 0.209\nsamples = 11\nvalue = 10.073'),
#  Text(0.8041237113402062, 0.5, 'x[0] <= 1.075\nsquared_error = 0.071\nsamples = 6\nvalue = 10.417'),
#  Text(0.7938144329896907, 0.4090909090909091, 'x[3] <= 163.75\nsquared_error = 0.023\nsamples = 2\nvalue = 10.75'),
#  Text(0.7896907216494845, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 10.6'),
#  Text(0.797938144329897, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 10.9'),
#  Text(0.8144329896907216, 0.4090909090909091, 'x[3] <= 171.5\nsquared_error = 0.013\nsamples = 4\nvalue = 10.25'),
#  Text(0.8061855670103093, 0.3181818181818182, 'x[4] <= 94.7\nsquared_error = 0.003\nsamples = 2\nvalue = 10.15'),
#  Text(0.8020618556701031, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.1'),
#  Text(0.8103092783505155, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.2'),
#  Text(0.822680412371134, 0.3181818181818182, 'x[3] <= 186.45\nsquared_error = 0.002\nsamples = 2\nvalue = 10.35'),
#  Text(0.8185567010309278, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.4'),
#  Text(0.8268041237113402, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 10.3'),
#  Text(0.843298969072165, 0.5, 'x[0] <= 1.077\nsquared_error = 0.062\nsamples = 5\nvalue = 9.66'),
#  Text(0.8350515463917526, 0.4090909090909091, 'x[1] <= 85.1\nsquared_error = 0.003\nsamples = 2\nvalue = 9.95'),
#  Text(0.8309278350515464, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 9.9'),
#  Text(0.8391752577319588, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 10.0'),
#  Text(0.8515463917525773, 0.4090909090909091, 'x[2] <= 96.35\nsquared_error = 0.009\nsamples = 3\nvalue = 9.467'),
#  Text(0.8474226804123711, 0.3181818181818182, 'x[2] <= 92.5\nsquared_error = 0.0\nsamples = 2\nvalue = 9.4'),
#  Text(0.843298969072165, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 9.4'),
#  Text(0.8515463917525773, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 9.4'),
#  Text(0.8556701030927835, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 9.6'),
#  Text(0.8927835051546392, 0.5909090909090909, 'x[0] <= 1.081\nsquared_error = 0.608\nsamples = 14\nvalue = 7.893'),
#  Text(0.8762886597938144, 0.5, 'x[3] <= 142.0\nsquared_error = 0.111\nsamples = 8\nvalue = 8.488'),
#  Text(0.8680412371134021, 0.4090909090909091, 'x[0] <= 1.081\nsquared_error = 0.002\nsamples = 2\nvalue = 7.95'),
#  Text(0.8639175257731959, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.8721649484536083, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 7.9'),
#  Text(0.8845360824742268, 0.4090909090909091, 'x[0] <= 1.079\nsquared_error = 0.019\nsamples = 6\nvalue = 8.667'),
#  Text(0.8804123711340206, 0.3181818181818182, 'squared_error = 0.0\nsamples = 3\nvalue = 8.8'),
#  Text(0.8886597938144329, 0.3181818181818182, 'x[4] <= 97.2\nsquared_error = 0.002\nsamples = 3\nvalue = 8.533'),
#  Text(0.8845360824742268, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 8.5'),
#  Text(0.8927835051546392, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 8.6'),
#  Text(0.9092783505154639, 0.5, 'x[0] <= 1.082\nsquared_error = 0.17\nsamples = 6\nvalue = 7.1'),
#  Text(0.9010309278350516, 0.4090909090909091, 'x[2] <= 89.2\nsquared_error = 0.01\nsamples = 2\nvalue = 7.6'),
#  Text(0.8969072164948454, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 7.7'),
#  Text(0.9051546391752577, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 7.5'),
#  Text(0.9175257731958762, 0.4090909090909091, 'x[0] <= 1.083\nsquared_error = 0.062\nsamples = 4\nvalue = 6.85'),
#  Text(0.9134020618556701, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 7.1'),
#  Text(0.9216494845360824, 0.3181818181818182, 'x[3] <= 153.25\nsquared_error = 0.0\nsamples = 2\nvalue = 6.6'),
#  Text(0.9175257731958762, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 6.6'),
#  Text(0.9257731958762887, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 6.6'),
#  Text(0.9762886597938144, 0.6818181818181818, 'x[0] <= 1.095\nsquared_error = 3.742\nsamples = 12\nvalue = 3.992'),
#  Text(0.9608247422680413, 0.5909090909090909, 'x[0] <= 1.089\nsquared_error = 1.284\nsamples = 10\nvalue = 4.72'),
#  Text(0.9422680412371134, 0.5, 'x[4] <= 94.1\nsquared_error = 0.198\nsamples = 5\nvalue = 5.78'),
#  Text(0.934020618556701, 0.4090909090909091, 'x[3] <= 143.0\nsquared_error = 0.003\nsamples = 2\nvalue = 5.25'),
#  Text(0.9298969072164949, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 5.2'),
#  Text(0.9381443298969072, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 5.3'),
#  Text(0.9505154639175257, 0.4090909090909091, 'x[4] <= 97.4\nsquared_error = 0.016\nsamples = 3\nvalue = 6.133'),
#  Text(0.9463917525773196, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 6.3'),
#  Text(0.954639175257732, 0.3181818181818182, 'x[2] <= 97.2\nsquared_error = 0.003\nsamples = 2\nvalue = 6.05'),
#  Text(0.9505154639175257, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 6.1'),
#  Text(0.9587628865979382, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.979381443298969, 0.5, 'x[1] <= 80.8\nsquared_error = 0.122\nsamples = 5\nvalue = 3.66'),
#  Text(0.9752577319587629, 0.4090909090909091, 'x[0] <= 1.091\nsquared_error = 0.017\nsamples = 4\nvalue = 3.825'),
#  Text(0.9711340206185567, 0.3181818181818182, 'x[3] <= 131.875\nsquared_error = 0.002\nsamples = 2\nvalue = 3.95'),
#  Text(0.9670103092783505, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.9752577319587629, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 3.9'),
#  Text(0.979381443298969, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 3.7'),
#  Text(0.9835051546391752, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.9917525773195877, 0.5909090909090909, 'x[0] <= 1.104\nsquared_error = 0.123\nsamples = 2\nvalue = 0.35'),
#  Text(0.9876288659793815, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 0.7'),
#  Text(0.9958762886597938, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0')]

# %%
path = reg.cost_complexity_pruning_path(X_train, y_train)
ccp_alpha = path.ccp_alphas

# %%
alphalist = []
for i in range(len(ccp_alpha)):
    reg = DecisionTreeRegressor(ccp_alpha=ccp_alpha[i])
    reg.fit(X_train, y_train)
    alphalist.append(reg)

# %%
trainscore = [alphalist[i].score(X_train, y_train) for i in range(len(alphalist))]
testscore = [alphalist[i].score(X_test, y_test) for i in range(len(alphalist))]

plt.xlabel('alpha')
plt.ylabel('accuracy')
plt.plot(ccp_alpha, trainscore, marker='o', label='training', color='magenta', drawstyle='steps-post')
plt.plot(ccp_alpha, testscore, marker='+', label='testing', color='red', drawstyle='steps-post')
plt.legend()
plt.show()

# %%
## normal approach
clf = DecisionTreeRegressor(ccp_alpha=1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(f'Decision Tree Normal Approach : {metrics.r2_score(y_test, y_pred)}')

rf = RandomForestRegressor(n_estimators=1000, ccp_alpha=1)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print(f'Random Forest Normal Approach : {metrics.r2_score(y_test, y_pred_rf)}')
# Out:
# Decision Tree Normal Approach : 0.9094810512291444
# Random Forest Normal Approach : 0.9347620041814746

# %%
params = {
    'RandomForest': {
        'model': RandomForestRegressor(),
        'params': {
            'n_estimators': [int(x) for x in np.linspace(start=1, stop=1200, num=10)],
            'criterion': ["squared_error", "absolute_error"],  # updated
            'max_depth': [int(x) for x in np.linspace(start=1, stop=30, num=5)],
            'min_samples_split': [2, 5, 10, 12],
            'min_samples_leaf': [2, 5, 10, 12],
            'max_features': ['auto', 'sqrt'],
            'ccp_alpha': [1, 2, 2.5, 3, 3.5, 4, 5],
        },
    },
    'D-tree': {
        'model': DecisionTreeRegressor(),
        'params': {
            'criterion': ["squared_error", "absolute_error"],  # updated
            'splitter': ['best', 'random'],
            'min_samples_split': [1, 2, 5, 10, 12],
            'min_samples_leaf': [1, 2, 5, 10, 12],
            'max_features': ['auto', 'sqrt'],
            'ccp_alpha': [1, 2, 2.5, 3, 3.5, 4, 5],
        },
    },
    'SVM': {
        'model': SVR(),
        'params': {
            'C': [0.25, 0.50, 0.75, 1.0],
            'tol': [1e-10, 1e-5, 1e-4, 0.025, 0.50, 0.75],
            'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
            'max_iter': [int(x) for x in np.linspace(start=1, stop=250, num=10)],
        },
    },
}

# %%
scores = []
for modelname, mp in params.items():
    clf = RandomizedSearchCV(mp['model'], param_distributions=mp['params'],
                             cv=5, n_jobs=-1, n_iter=10, scoring='neg_mean_squared_error')

    clf.fit(X_train, y_train)
    scores.append({
        'model_name': modelname,
        'best_score': clf.best_score_,
        'best_estimator': clf.best_estimator_
    })
# Out:
# C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 9 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 16 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [-38.71638468          nan -39.11995444          nan -30.97144859
#           nan -31.19370165          nan          nan -31.21610239]
#   warnings.warn(
# C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 30 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 11 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of DecisionTreeRegressor must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [-21.43855069 -45.29445152          nan          nan          nan
#           nan -74.66423902          nan -15.1908534           nan]
#   warnings.warn(
# C:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=167).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
scoresdf = pd.DataFrame(scores, columns=['model_name', 'best_score', 'best_estimator'])
scoresdf
# Out:
#      model_name  best_score                                     best_estimator
# 0  RandomForest  -30.971449  (DecisionTreeRegressor(ccp_alpha=2, criterion=...
# 1        D-tree  -15.190853  DecisionTreeRegressor(ccp_alpha=1, max_feature...
# 2           SVM  -30.265795  SVR(C=0.5, kernel='poly', max_iter=167, tol=0.75)

# %%
scores[0]['best_estimator']
# Out:
# RandomForestRegressor(ccp_alpha=2, criterion='absolute_error', max_depth=30,
#                       max_features='sqrt', min_samples_leaf=2,
#                       min_samples_split=5, n_estimators=800)

# %%
rf = RandomForestRegressor(n_estimators=1000, ccp_alpha=1)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

print(metrics.r2_score(y_test, y_pred))
# Out:
# 0.9350222988260782

# %%
# Create a copy of totrain without the 'Actual Result' and 'Predicted Result'
features = totrain.drop(columns=['Actual Result', 'Predicted Result'], errors='ignore')

predicted = []
for i in range(len(features)):
    predicted.append(rf.predict(features.iloc[[i]]))  # Use the DataFrame with original feature names

totrain['Actual Result'] = test
totrain['Predicted Result'] = np.array(predicted)
totrain
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\2858122874.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totrain['Actual Result'] = test
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24388\2858122874.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totrain['Predicted Result'] = np.array(predicted)
#      Density  Abdomen  Chest  Weight    Hip  Actual Result  Predicted Result
# 0     1.0708     85.2   93.1  154.25   94.5           12.3         12.811484
# 1     1.0853     83.0   93.6  173.25   98.7            6.1          6.667474
# 2     1.0414     87.9   95.8  154.00   99.2           25.3         25.168634
# 3     1.0751     86.4  101.8  184.75  101.2           10.4          9.066627
# 4     1.0340    100.0   97.3  184.25  101.9           28.7         30.274403
# ..       ...      ...    ...     ...    ...            ...               ...
# 247   1.0736     83.6   89.2  134.25   88.8           11.0         10.612939
# 248   1.0236    105.0  108.5  201.00  104.5           33.6         32.198251
# 249   1.0328    111.5  111.1  186.75  101.7           29.3         30.722925
# 250   1.0399    101.3  108.3  190.75   97.8           26.0         25.425822
# 251   1.0271    108.5  112.4  207.50  107.1           31.9         31.889534
#
# [252 rows x 7 columns]

# %%
sn.kdeplot(totrain['Actual Result'], label='Actual Result', color='magenta')
sn.kdeplot(totrain['Predicted Result'], label='Predicted Result', color='red')
plt.legend()
plt.show()

# %%
sn.kdeplot(totrain['Actual Result'], label='Actual Result', color='magenta')
sn.kdeplot(totrain['Predicted Result'], label='Predicted Result', color='red')
plt.legend()
plt.show()

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: pillow>=8 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'C:\Users\shubh\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sn
sn.kdeplot(totrain['Actual Result'], label='Actual Result', color='magenta')
sn.kdeplot(totrain['Predicted Result'], label='Predicted Result', color='red')
plt.legend()
plt.show()

# %%
# saving the model
import pickle
file = open('bodyfatmodel1.pkl', 'wb')
pickle.dump(rf, file)
file.close()
